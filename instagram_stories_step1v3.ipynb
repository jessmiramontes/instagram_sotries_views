# %% [markdown]
# <a href="https://colab.research.google.com/github/jessmiramontes/instagram_sotries_views/blob/imagesdataset/instagram_stories_step1v3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Analyze images of my IG stories, create a Dataframe and export it to a csv file so I can combine this dataset with the Analytics given by Meta.

# %% [markdown]
# **First attempt:** All values on the "dominant color" column are Unknown
# Not sure that the objects recognized are correct.
#
# **Second attempt:** Instead of translating colors to a name, I decided to let them as HEX values.
#
# **Next step:** See if the object recognition can be improved because on the first attempt objects were recognized but not all of them were correct. I used ResNet50 for object recognition, next I will try YOLOv5.
#
# **Update Jan 24:** YOLOv5 did a better job recognizing but the most important object in all images is a person so that is not helpful for prediction. I will combine ResNet50 and YOLOv5 as well as MobileNet to detect the activity and clothing.  Added error handling for when a file can't be read. The function adds the name to the DataFrame and NA in the other fields. Result: No activities or clothes were detected so I will remove that. I wonder what can be done with YOLOv5. But I will let the dataset as is and move now to combine it with the Analytics given by Meta.

# %%
# Install requerid libraries
# !pip install tensorflow
# !pip install opencv-python-headless
# !pip install deepface
# !pip install pytesseract
# !pip install pandas
# !pip install Pillow
# !pip install yolov5
# !wget -O mobilenet_iter_73000.caffemodel https://github.com/chenyuntc/simple-faster-rcnn-pytorch/raw/master/models/mobilenet_iter_73000.caffemodel
# !wget -O deploy.prototxt https://github.com/chenyuntc/simple-faster-rcnn-pytorch/raw/master/models/MobileNetSSD_deploy.prototxt
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.17.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.1.21)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.69.0)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->tensorflow) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.11/dist-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-python-headless) (1.26.4)
# Requirement already satisfied: deepface in /usr/local/lib/python3.11/dist-packages (0.0.93)
# Requirement already satisfied: requests>=2.27.1 in /usr/local/lib/python3.11/dist-packages (from deepface) (2.32.3)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from deepface) (1.26.4)
# Requirement already satisfied: pandas>=0.23.4 in /usr/local/lib/python3.11/dist-packages (from deepface) (2.2.2)
# Requirement already satisfied: gdown>=3.10.1 in /usr/local/lib/python3.11/dist-packages (from deepface) (5.2.0)
# Requirement already satisfied: tqdm>=4.30.0 in /usr/local/lib/python3.11/dist-packages (from deepface) (4.67.1)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.11/dist-packages (from deepface) (11.1.0)
# Requirement already satisfied: opencv-python>=4.5.5.64 in /usr/local/lib/python3.11/dist-packages (from deepface) (4.10.0.84)
# Requirement already satisfied: tensorflow>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from deepface) (2.17.1)
# Requirement already satisfied: keras>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from deepface) (3.5.0)
# Requirement already satisfied: Flask>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from deepface) (3.1.0)
# Requirement already satisfied: flask-cors>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from deepface) (5.0.0)
# Requirement already satisfied: mtcnn>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from deepface) (1.0.0)
# Requirement already satisfied: retina-face>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from deepface) (0.0.17)
# Requirement already satisfied: fire>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from deepface) (0.7.0)
# Requirement already satisfied: gunicorn>=20.1.0 in /usr/local/lib/python3.11/dist-packages (from deepface) (23.0.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from fire>=0.4.0->deepface) (2.5.0)
# Requirement already satisfied: Werkzeug>=3.1 in /usr/local/lib/python3.11/dist-packages (from Flask>=1.1.2->deepface) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from Flask>=1.1.2->deepface) (3.1.5)
# Requirement already satisfied: itsdangerous>=2.2 in /usr/local/lib/python3.11/dist-packages (from Flask>=1.1.2->deepface) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.11/dist-packages (from Flask>=1.1.2->deepface) (8.1.8)
# Requirement already satisfied: blinker>=1.9 in /usr/local/lib/python3.11/dist-packages (from Flask>=1.1.2->deepface) (1.9.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown>=3.10.1->deepface) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from gdown>=3.10.1->deepface) (3.17.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from gunicorn>=20.1.0->deepface) (24.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from keras>=2.2.0->deepface) (1.4.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=2.2.0->deepface) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=2.2.0->deepface) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from keras>=2.2.0->deepface) (3.12.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=2.2.0->deepface) (0.14.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.11/dist-packages (from keras>=2.2.0->deepface) (0.4.1)
# Requirement already satisfied: joblib>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from mtcnn>=0.1.0->deepface) (1.4.2)
# Requirement already satisfied: lz4>=4.3.3 in /usr/local/lib/python3.11/dist-packages (from mtcnn>=0.1.0->deepface) (4.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.23.4->deepface) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.23.4->deepface) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.23.4->deepface) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27.1->deepface) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27.1->deepface) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27.1->deepface) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.27.1->deepface) (2024.12.14)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=1.9.0->deepface) (25.1.21)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=1.9.0->deepface) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=1.9.0->deepface) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=1.9.0->deepface) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=1.9.0->deepface) (4.25.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow>=1.9.0->deepface) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=1.9.0->deepface) (1.17.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=1.9.0->deepface) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=1.9.0->deepface) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=1.9.0->deepface) (1.69.0)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=1.9.0->deepface) (2.17.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=1.9.0->deepface) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow>=1.9.0->deepface) (0.45.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2>=3.1.2->Flask>=1.1.2->deepface) (3.0.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.18,>=2.17->tensorflow>=1.9.0->deepface) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.18,>=2.17->tensorflow>=1.9.0->deepface) (0.7.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.6)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=2.2.0->deepface) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=2.2.0->deepface) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=2.2.0->deepface) (0.1.2)
# Requirement already satisfied: pytesseract in /usr/local/lib/python3.11/dist-packages (0.3.13)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from pytesseract) (24.2)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from pytesseract) (11.1.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (11.1.0)
# Requirement already satisfied: yolov5 in /usr/local/lib/python3.11/dist-packages (7.0.14)
# Requirement already satisfied: gitpython>=3.1.30 in /usr/local/lib/python3.11/dist-packages (from yolov5) (3.1.44)
# Requirement already satisfied: matplotlib>=3.3 in /usr/local/lib/python3.11/dist-packages (from yolov5) (3.10.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.11/dist-packages (from yolov5) (1.26.4)
# Requirement already satisfied: opencv-python>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from yolov5) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from yolov5) (11.1.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from yolov5) (5.9.5)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from yolov5) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from yolov5) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from yolov5) (1.13.1)
# Requirement already satisfied: thop>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from yolov5) (0.1.1.post2209072238)
# Requirement already satisfied: torch>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from yolov5) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.8.1 in /usr/local/lib/python3.11/dist-packages (from yolov5) (0.20.1+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from yolov5) (4.67.1)
# Requirement already satisfied: ultralytics>=8.0.100 in /usr/local/lib/python3.11/dist-packages (from yolov5) (8.3.67)
# Requirement already satisfied: tensorboard>=2.4.1 in /usr/local/lib/python3.11/dist-packages (from yolov5) (2.17.1)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from yolov5) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from yolov5) (0.13.2)
# Requirement already satisfied: setuptools>=65.5.1 in /usr/local/lib/python3.11/dist-packages (from yolov5) (75.1.0)
# Requirement already satisfied: fire in /usr/local/lib/python3.11/dist-packages (from yolov5) (0.7.0)
# Requirement already satisfied: boto3>=1.19.1 in /usr/local/lib/python3.11/dist-packages (from yolov5) (1.36.6)
# Requirement already satisfied: sahi>=0.11.10 in /usr/local/lib/python3.11/dist-packages (from yolov5) (0.11.20)
# Requirement already satisfied: huggingface-hub<0.25.0,>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from yolov5) (0.24.7)
# Requirement already satisfied: roboflow>=0.2.29 in /usr/local/lib/python3.11/dist-packages (from yolov5) (1.1.51)
# Requirement already satisfied: botocore<1.37.0,>=1.36.6 in /usr/local/lib/python3.11/dist-packages (from boto3>=1.19.1->yolov5) (1.36.6)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from boto3>=1.19.1->yolov5) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from boto3>=1.19.1->yolov5) (0.11.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython>=3.1.30->yolov5) (4.0.12)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<0.25.0,>=0.12.0->yolov5) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<0.25.0,>=0.12.0->yolov5) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<0.25.0,>=0.12.0->yolov5) (24.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<0.25.0,>=0.12.0->yolov5) (4.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->yolov5) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->yolov5) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->yolov5) (4.55.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->yolov5) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->yolov5) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->yolov5) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->yolov5) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->yolov5) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->yolov5) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->yolov5) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->yolov5) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->yolov5) (2024.12.14)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /usr/local/lib/python3.11/dist-packages (from roboflow>=0.2.29->yolov5) (4.10.0.84)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.11/dist-packages (from roboflow>=0.2.29->yolov5) (1.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from roboflow>=0.2.29->yolov5) (1.17.0)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.11/dist-packages (from roboflow>=0.2.29->yolov5) (1.0.0)
# Requirement already satisfied: filetype in /usr/local/lib/python3.11/dist-packages (from roboflow>=0.2.29->yolov5) (1.2.0)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from sahi>=0.11.10->yolov5) (2.0.6)
# Requirement already satisfied: pybboxes==0.1.6 in /usr/local/lib/python3.11/dist-packages (from sahi>=0.11.10->yolov5) (0.1.6)
# Requirement already satisfied: terminaltables in /usr/local/lib/python3.11/dist-packages (from sahi>=0.11.10->yolov5) (3.1.10)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from sahi>=0.11.10->yolov5) (8.1.8)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.4.1->yolov5) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.4.1->yolov5) (1.69.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.4.1->yolov5) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.4.1->yolov5) (4.25.5)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.4.1->yolov5) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.4.1->yolov5) (3.1.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->yolov5) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->yolov5) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->yolov5) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->yolov5) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->yolov5) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->yolov5) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->yolov5) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->yolov5) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->yolov5) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->yolov5) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->yolov5) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->yolov5) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->yolov5) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->yolov5) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->yolov5) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.7.0->yolov5) (12.6.85)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.7.0->yolov5) (1.3.0)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics>=8.0.100->yolov5) (9.0.0)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics>=8.0.100->yolov5) (2.0.14)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from fire->yolov5) (2.5.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30->yolov5) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.4.1->yolov5) (3.0.2)
# --2025-01-25 01:24:34--  https://github.com/chenyuntc/simple-faster-rcnn-pytorch/raw/master/models/mobilenet_iter_73000.caffemodel
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-01-25 01:24:34 ERROR 404: Not Found.
#
# --2025-01-25 01:24:34--  https://github.com/chenyuntc/simple-faster-rcnn-pytorch/raw/master/models/MobileNetSSD_deploy.prototxt
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-01-25 01:24:34 ERROR 404: Not Found.

# %%
# Import libraries
import os
import pandas as pd
import cv2
from PIL import Image as PILImage, UnidentifiedImageError  # Import UnidentifiedImageError
import numpy as np
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input, decode_predictions
from tensorflow.keras.preprocessing import image
import torch
from deepface import DeepFace
import pytesseract
from google.colab import drive

# %%
# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load pre-trained YOLOv5 and ResNet50 models
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
resnet_model = ResNet50(weights='imagenet')
#net = cv2.dnn.readNetFromCaffe('deploy.prototxt', 'mobilenet_iter_73000.caffemodel')  # Load MobileNet model
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2025-1-25 Python-3.11.11 torch-2.5.1+cu121 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
# Initialize the ResNet50 model
#model = ResNet50(weights='imagenet')

# %%
# Function to extract date from filename
def extract_date(filename):
    date_str = filename.split('_')[1]
    return pd.to_datetime(date_str, format='%Y%m%d')

# %%
# Load YOLOv5 and ResNet50 models
## model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
## resnet_model = ResNet50(weights='imagenet')

# New object detection function using YOLOv5 with error handling
def detect_object_yolo(img_path):
    try:
        results = model(img_path)
        if results:
            labels = results.names
            coords = results.xyxy[0][:4]
            obj = labels[0] if labels else "Unknown"
            return obj
    except UnidentifiedImageError as e:
      ##  print(f"Error identifying image {img_path}: {e}")
        return 'Unknown'
    except Exception as e:
        ## print(f"Unexpected error processing {img_path}: {e}")
        return 'Unknown'
    return 'Unknown'


# Function to use ResNet50 for animal and specific object detection
def detect_resnet_objects(img_path):
    img = PILImage.open(img_path)
    img = img.resize((224, 224))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    preds = resnet_model.predict(x)
    return decode_predictions(preds, top=1)[0][0][1]

# Function to combine YOLOv5 and ResNet50
def detect_hybrid_objects(img_path):
    yolo_obj = detect_object_yolo(img_path)
    resnet_obj = detect_resnet_objects(img_path)

    if yolo_obj.lower() != 'person' and yolo_obj != 'Unknown':
        return yolo_obj
    elif resnet_obj.lower() != 'unknown':
        return resnet_obj
    else:
        return 'Object unknown'  # Fallback value if both return "Unknown"

# %%
# Load the MobileNet model
net = None

try:
    net = cv2.dnn.readNetFromCaffe('deploy.prototxt', 'mobilenet_iter_73000.caffemodel')
except Exception as e:
    print(f"Error loading MobileNet model: {e}")

def recognize_activity(img_path):
    try:
        net = cv2.dnn.readNetFromCaffe('deploy.prototxt', 'mobilenet_iter_73000.caffemodel')
        img = cv2.imread(img_path)
        if img is None:
            print(f"Error: Unable to read image file {img_path}")
            return 'Unknown'

        blob = cv2.dnn.blobFromImage(cv2.resize(img, (224, 224)), 0.007843, (224, 224), 127.5)
        net.setInput(blob)
        detections = net.forward()

        if detections.shape[2] > 0:
            activity = detections[0, 0, 0, 1]
            conf_score = detections[0, 0, 0, 2]
            return activity if conf_score > 0.5 else 'Unknown'
    except Exception as e:
       ## print(f"Error during activity recognition for {img_path}: {e}")
        return 'Unknown'

    return 'Unknown'

# %%
def detect_clothing(img_path):
    try:
        results = model(img_path)
        labels = results.names if results.names else []
        clothing_items = [label for label in labels if isinstance(label, str) and 'clothing' in label]
        return clothing_items if clothing_items else ['Unknown']
    except Exception as e:
        print(f"Error during clothing detection for {img_path}: {e}")
        return ['Unknown']

# %%
# Function to convert RGB to hex color code
def rgb_to_hex(rgb_array):
    return '#%02x%02x%02x' % tuple(rgb_array)

# Updated function to analyze dominant color with error handling and returning hex values
def dominant_color(img_path):
    img = cv2.imread(img_path)
    if img is None:
        print(f"Error: Unable to read image file {img_path}")
        return 'Unknown'

    data = np.reshape(img, (-1, 3))
    data = np.float32(data)
    _, _, centers = cv2.kmeans(data, 1, None, (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 100, 0.2), 10, cv2.KMEANS_RANDOM_CENTERS)
    dominant_color_rgb = centers[0].astype(int)
    dominant_color_hex = rgb_to_hex(dominant_color_rgb)
   # print(f"Dominant RGB values for {img_path}: {dominant_color_rgb}")  # Debugging statement
   # print(f"Dominant hex value for {img_path}: {dominant_color_hex}")  # Debugging statement
    return dominant_color_hex

# %%
# Function to detect emotions, will return "no face detected" if there are no faces on the image
def analyze_emotion(img_path):
    try:
        result = DeepFace.analyze(img_path, actions=['emotion'], enforce_detection=False)
        #print(result)  # Print the result to understand its structure
        if isinstance(result, list) and len(result) > 0:
            return result[0]['dominant_emotion'] if 'dominant_emotion' in result[0] else None
        return None
    except ValueError as e:
        print(f"Error analyzing emotion in {img_path}: {e}")
        return 'No face detected'  # Or any other default value you prefer

# %%
# Directory of images in Google Drive
image_directory = '/content/drive/MyDrive/Colab Notebooks/stories_archive'

# %%
# List to store results
image_data = []

# %%
# Process each image in the directory
for filename in os.listdir(image_directory):
    if filename.endswith('.jpg') or filename.endswith('.webp'):  # Adjust for your image extensions
        # print(f"Processing {filename}")
        img_path = os.path.join(image_directory, filename)

        try:

          date = extract_date(filename)
          obj = detect_hybrid_objects(img_path)
          color = dominant_color(img_path)
          emotion = analyze_emotion(img_path)
          activity = recognize_activity(img_path)
          clothing = detect_clothing(img_path)

          image_data.append({
            'nombre_archivo': filename,
            'fecha': date,
            'objeto_principal': obj,
            'color_dominante': color,
            'emocion_primaria': emotion,
            'actividad_detectada': activity,
            'ropa_detectada': clothing
        })



        except UnidentifiedImageError:
            # Handle the error and append 'NA' to image_data list
            image_data.append({
                'nombre_archivo': filename,
                'fecha': 'NA',
                'objeto_principal': 'NA',
                'color_dominante': 'NA',
                'emocion_primaria': 'NA',
                'actividad_detectada': 'NA',
                'ropa_detectada': 'NA'
            })
            print(f"Skipped {filename} due to unidentifiable image.")

print("Finished processing all images.")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# Skipped IMG_20240902_094755_286.jpg due to unidentifiable image.
# Skipped IMG_20240902_094358_122.jpg due to unidentifiable image.
# Skipped IMG_20240901_142009_712.jpg due to unidentifiable image.
# Skipped IMG_20240901_113922_180.jpg due to unidentifiable image.
# Skipped IMG_20240901_113921_892.jpg due to unidentifiable image.
# Skipped IMG_20240901_113919_888.jpg due to unidentifiable image.
# Skipped IMG_20240901_113918_911.jpg due to unidentifiable image.
# Skipped IMG_20240831_120114_836.jpg due to unidentifiable image.
# Skipped IMG_20240830_113134_601.jpg due to unidentifiable image.
# Skipped IMG_20240829_153816_351.jpg due to unidentifiable image.
# Skipped IMG_20240829_153625_328.jpg due to unidentifiable image.
# Skipped IMG_20240828_115454_915.jpg due to unidentifiable image.
# Skipped IMG_20240827_170051_835.jpg due to unidentifiable image.
# Skipped IMG_20240826_133346_199.jpg due to unidentifiable image.
# Skipped IMG_20240826_133208_186.jpg due to unidentifiable image.
# Skipped IMG_20240824_184445_872.jpg due to unidentifiable image.
# Skipped IMG_20240821_155819_331.jpg due to unidentifiable image.
# Skipped IMG_20240819_092100_941.jpg due to unidentifiable image.
# Skipped IMG_20240811_145554_516.jpg due to unidentifiable image.
# Skipped IMG_20240811_102840_917.jpg due to unidentifiable image.
# Skipped IMG_20240811_102832_102.jpg due to unidentifiable image.
# Skipped IMG_20240810_142353_431.jpg due to unidentifiable image.
# Skipped IMG_20240810_124511_027.jpg due to unidentifiable image.
# Skipped IMG_20240810_103612_969.jpg due to unidentifiable image.
# Skipped IMG_20240809_165928_655.jpg due to unidentifiable image.
# Skipped IMG_20240809_145528_681.jpg due to unidentifiable image.
# Skipped IMG_20240808_210516_193.jpg due to unidentifiable image.
# Skipped IMG_20240808_100350_212.jpg due to unidentifiable image.
# Skipped IMG_20240808_095858_487.jpg due to unidentifiable image.
# Skipped IMG_20240528_133155_716.jpg due to unidentifiable image.
# Skipped IMG_20240522_121200_500.jpg due to unidentifiable image.
# Skipped IMG_20240522_121157_356.jpg due to unidentifiable image.
# Skipped IMG_20240522_121153_867.jpg due to unidentifiable image.
# Skipped IMG_20240522_121151_924.jpg due to unidentifiable image.
# Skipped IMG_20240522_121150_701.jpg due to unidentifiable image.
# Skipped IMG_20240522_121149_820.jpg due to unidentifiable image.
# Skipped IMG_20240522_121148_486.jpg due to unidentifiable image.
# Skipped IMG_20240513_122744_822.jpg due to unidentifiable image.
# Skipped IMG_20240513_122742_155.jpg due to unidentifiable image.
# Skipped IMG_20240510_203822_689.jpg due to unidentifiable image.
# Skipped IMG_20240510_203822_065.jpg due to unidentifiable image.
# Skipped IMG_20240510_203821_648.jpg due to unidentifiable image.
# Skipped IMG_20240506_115821_119.jpg due to unidentifiable image.
# Skipped IMG_20240506_105807_119.jpg due to unidentifiable image.
# Skipped IMG_20240506_105807_560.jpg due to unidentifiable image.
# Skipped IMG_20240504_161359_463.jpg due to unidentifiable image.
# Skipped IMG_20240504_161357_968.jpg due to unidentifiable image.
# Skipped IMG_20240504_161356_203.jpg due to unidentifiable image.
# Skipped IMG_20240504_161354_243.jpg due to unidentifiable image.
# Skipped IMG_20240504_161343_341.jpg due to unidentifiable image.
# Skipped IMG_20240503_170518_854.jpg due to unidentifiable image.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# Skipped IMG_20240501_174852_821.jpg due to unidentifiable image.
# Skipped IMG_20240425_183425_441.jpg due to unidentifiable image.
# Skipped IMG_20240425_152212_626.jpg due to unidentifiable image.
# Skipped IMG_20240425_152211_383.jpg due to unidentifiable image.
# Skipped IMG_20240425_152209_075.jpg due to unidentifiable image.
# Skipped IMG_20240425_152208_168.jpg due to unidentifiable image.
# Skipped IMG_20240425_123732_797.jpg due to unidentifiable image.
# Skipped IMG_20240425_100117_624.jpg due to unidentifiable image.
# Skipped IMG_20240425_094228_479.jpg due to unidentifiable image.
# Skipped IMG_20240424_155033_295.jpg due to unidentifiable image.
# Skipped IMG_20240424_154915_528.jpg due to unidentifiable image.
# Skipped IMG_20240424_140855_977.jpg due to unidentifiable image.
# Skipped IMG_20240419_135448_157.jpg due to unidentifiable image.
# Skipped IMG_20240419_084956_981.jpg due to unidentifiable image.
# Skipped IMG_20240410_210243_566.jpg due to unidentifiable image.
# Skipped IMG_20240405_172930_524.jpg due to unidentifiable image.
# Skipped IMG_20240405_172839_010.jpg due to unidentifiable image.
# Skipped IMG_20240404_173737_841.jpg due to unidentifiable image.
# Skipped IMG_20240401_182702_590.jpg due to unidentifiable image.
# Skipped IMG_20240401_114436_157.jpg due to unidentifiable image.
# Skipped IMG_20240401_114430_919.jpg due to unidentifiable image.
# Skipped IMG_20240401_114431_278.jpg due to unidentifiable image.
# Skipped IMG_20240321_091929_583.jpg due to unidentifiable image.
# Skipped IMG_20240321_091929_670.jpg due to unidentifiable image.
# Skipped IMG_20240319_082946_013.jpg due to unidentifiable image.
# Skipped IMG_20240319_082946_383.jpg due to unidentifiable image.
# Skipped IMG_20240319_082943_526.jpg due to unidentifiable image.
# Skipped IMG_20240319_082940_712.jpg due to unidentifiable image.
# Skipped IMG_20240316_184103_346.jpg due to unidentifiable image.
# Skipped IMG_20240311_175941_185.jpg due to unidentifiable image.
# Skipped IMG_20240311_175939_070.jpg due to unidentifiable image.
# Skipped IMG_20240305_193348_099.jpg due to unidentifiable image.
# Skipped IMG_20240305_193343_615.jpg due to unidentifiable image.
# Skipped IMG_20240305_193343_959.jpg due to unidentifiable image.
# Skipped IMG_20240304_101907_511.jpg due to unidentifiable image.
# Skipped IMG_20240304_101907_513.jpg due to unidentifiable image.
# Skipped IMG_20240304_101907_606.jpg due to unidentifiable image.
# Skipped IMG_20240227_192245_237.jpg due to unidentifiable image.
# Skipped IMG_20240227_192232_482.jpg due to unidentifiable image.
# Skipped IMG_20240227_192215_674.jpg due to unidentifiable image.
# Skipped IMG_20240223_075821_075.jpg due to unidentifiable image.
# Skipped IMG_20240223_075818_734.jpg due to unidentifiable image.
# Skipped IMG_20240223_075817_564.jpg due to unidentifiable image.
# Skipped IMG_20240223_075816_795.jpg due to unidentifiable image.
# Skipped IMG_20240223_075815_658.jpg due to unidentifiable image.
# Skipped IMG_20240221_193431_128.jpg due to unidentifiable image.
# Skipped IMG_20240221_193428_114.jpg due to unidentifiable image.
# Skipped IMG_20240220_145706_258.jpg due to unidentifiable image.
# Skipped IMG_20240220_145706_307.jpg due to unidentifiable image.
# Skipped IMG_20240220_145703_283.jpg due to unidentifiable image.
# Skipped IMG_20240219_125100_027.jpg due to unidentifiable image.
# Skipped IMG_20240219_125058_731.jpg due to unidentifiable image.
# Skipped IMG_20240219_125056_353.jpg due to unidentifiable image.
# Skipped IMG_20240219_111146_466.jpg due to unidentifiable image.
# Skipped IMG_20240216_152701_550.jpg due to unidentifiable image.
# Skipped IMG_20240213_183250_806.jpg due to unidentifiable image.
# Skipped IMG_20240212_121301_845.jpg due to unidentifiable image.
# Skipped IMG_20240212_121300_506.jpg due to unidentifiable image.
# Skipped IMG_20240212_121257_181.jpg due to unidentifiable image.
# Skipped IMG_20240210_163013_969.jpg due to unidentifiable image.
# Skipped IMG_20240210_163012_710.jpg due to unidentifiable image.
# Skipped IMG_20240207_110906_769.jpg due to unidentifiable image.
# Skipped IMG_20240202_105325_912.jpg due to unidentifiable image.
# Skipped IMG_20240130_190930_660.jpg due to unidentifiable image.
# Skipped IMG_20240129_143555_250.jpg due to unidentifiable image.
# Skipped IMG_20240111_180951_112.jpg due to unidentifiable image.
# Skipped IMG_20240106_214222_344.jpg due to unidentifiable image.
# Skipped IMG_20240105_140833_389.jpg due to unidentifiable image.
# Skipped IMG_20240104_151311_107.jpg due to unidentifiable image.
# Skipped IMG_20240103_091845_755.jpg due to unidentifiable image.
# Skipped IMG_20240103_091845_420.jpg due to unidentifiable image.
# Skipped IMG_20240101_120057_494.jpg due to unidentifiable image.
# Skipped IMG_20231231_121800_778.jpg due to unidentifiable image.
# Skipped IMG_20231229_154437_750.jpg due to unidentifiable image.
# Skipped IMG_20231229_120935_441.jpg due to unidentifiable image.
# Skipped IMG_20231228_092223_407.jpg due to unidentifiable image.
# Skipped IMG_20231227_170637_259.jpg due to unidentifiable image.
# Skipped IMG_20231225_151219_549.jpg due to unidentifiable image.
# Skipped IMG_20231225_111317_831.jpg due to unidentifiable image.
# Skipped IMG_20231223_110559_012.jpg due to unidentifiable image.
# Skipped IMG_20231223_110557_952.jpg due to unidentifiable image.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step
# Skipped IMG_20231222_182817_998.jpg due to unidentifiable image.
# Skipped IMG_20231220_175120_219.jpg due to unidentifiable image.
# Skipped IMG_20231218_173716_965.jpg due to unidentifiable image.
# Skipped IMG_20231214_185323_269.jpg due to unidentifiable image.
# Skipped IMG_20231213_131509_899.jpg due to unidentifiable image.
# Skipped IMG_20231213_131506_349.jpg due to unidentifiable image.
# Skipped IMG_20231210_152007_252.jpg due to unidentifiable image.
# Skipped IMG_20231208_095334_773.jpg due to unidentifiable image.
# Skipped IMG_20231208_094046_142.jpg due to unidentifiable image.
# Skipped IMG_20231205_140027_922.jpg due to unidentifiable image.
# Skipped IMG_20231204_093227_861.jpg due to unidentifiable image.
# Skipped IMG_20231203_153112_005.jpg due to unidentifiable image.
# Skipped IMG_20231202_111442_911.jpg due to unidentifiable image.
# Skipped IMG_20231201_080738_765.jpg due to unidentifiable image.
# Skipped IMG_20231129_092822_072.jpg due to unidentifiable image.
# Skipped IMG_20231127_115721_790.jpg due to unidentifiable image.
# Skipped IMG_20231120_114518_579.jpg due to unidentifiable image.
# Skipped IMG_20231114_171018_259.jpg due to unidentifiable image.
# Skipped IMG_20231113_124011_527.jpg due to unidentifiable image.
# Skipped IMG_20231112_180053_149.jpg due to unidentifiable image.
# Skipped IMG_20231112_171252_100.jpg due to unidentifiable image.
# Skipped IMG_20231112_151040_848.jpg due to unidentifiable image.
# Skipped IMG_20231109_151903_858.jpg due to unidentifiable image.
# Skipped IMG_20231108_111512_394.jpg due to unidentifiable image.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# Skipped IMG_20231105_180430_244.jpg due to unidentifiable image.
# Skipped IMG_20231105_161114_813.jpg due to unidentifiable image.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step
# Skipped IMG_20231101_162415_442.jpg due to unidentifiable image.
# Skipped IMG_20231101_111546_032.jpg due to unidentifiable image.
# Skipped IMG_20231031_180907_348.jpg due to unidentifiable image.
# Skipped IMG_20231031_173742_753.jpg due to unidentifiable image.
# Skipped IMG_20231031_104302_997.jpg due to unidentifiable image.
# Skipped IMG_20231031_090116_142.jpg due to unidentifiable image.
# Skipped IMG_20231030_134200_340.jpg due to unidentifiable image.
# Skipped IMG_20231029_161144_271.jpg due to unidentifiable image.
# Skipped IMG_20231027_211007_172.jpg due to unidentifiable image.
# Skipped IMG_20231025_185900_681.jpg due to unidentifiable image.
# Skipped IMG_20231023_111222_164.jpg due to unidentifiable image.
# Skipped IMG_20231019_101739_145.jpg due to unidentifiable image.
# Skipped IMG_20231017_073117_525.jpg due to unidentifiable image.
# Skipped IMG_20231016_111931_352.jpg due to unidentifiable image.
# Skipped IMG_20231014_183052_868.jpg due to unidentifiable image.
# Skipped IMG_20231005_144335_085.jpg due to unidentifiable image.
# Skipped IMG_20231004_145727_231.jpg due to unidentifiable image.
# Skipped IMG_20231002_195655_366.jpg due to unidentifiable image.
# Skipped IMG_20231002_112036_587.jpg due to unidentifiable image.
# Skipped IMG_20231002_111757_682.jpg due to unidentifiable image.
# Skipped IMG_20231001_110448_650.jpg due to unidentifiable image.
# Skipped IMG_20230929_105901_289.jpg due to unidentifiable image.
# Skipped IMG_20230926_155613_230.jpg due to unidentifiable image.
# Skipped IMG_20230922_112624_757.jpg due to unidentifiable image.
# Skipped IMG_20230919_224225_448.jpg due to unidentifiable image.
# Skipped IMG_20230919_211326_765.jpg due to unidentifiable image.
# Skipped IMG_20230918_132526_627.jpg due to unidentifiable image.
# Skipped IMG_20230913_091736_225.jpg due to unidentifiable image.
# Skipped IMG_20230912_145926_671.jpg due to unidentifiable image.
# Skipped IMG_20230910_210112_254.jpg due to unidentifiable image.
# Skipped IMG_20230910_174741_622.jpg due to unidentifiable image.
# Skipped IMG_20230910_124252_716.jpg due to unidentifiable image.
# Skipped IMG_20230907_184339_257.jpg due to unidentifiable image.
# Skipped IMG_20230903_104309_535.jpg due to unidentifiable image.
# Skipped IMG_20230903_104252_723.jpg due to unidentifiable image.
# Skipped IMG_20230903_104241_435.jpg due to unidentifiable image.
# Skipped IMG_20230903_104230_105.jpg due to unidentifiable image.
# Skipped IMG_20230903_104131_270.jpg due to unidentifiable image.
# Skipped IMG_20230902_115445_382.jpg due to unidentifiable image.
# Skipped IMG_20230901_192630_079.jpg due to unidentifiable image.
# Skipped IMG_20230831_150332_484.jpg due to unidentifiable image.
# Skipped IMG_20230814_123530_258.jpg due to unidentifiable image.
# Skipped IMG_20230812_214342_621.jpg due to unidentifiable image.
# Skipped IMG_20230810_160457_093.jpg due to unidentifiable image.
# Skipped IMG_20230810_101951_474.jpg due to unidentifiable image.
# Skipped IMG_20230808_194851_186.jpg due to unidentifiable image.
# Skipped IMG_20230803_143127_552.jpg due to unidentifiable image.
# Skipped IMG_20230727_204800_793.jpg due to unidentifiable image.
# Skipped IMG_20230722_091940_212.jpg due to unidentifiable image.
# Skipped IMG_20230722_082352_222.jpg due to unidentifiable image.
# Skipped IMG_20230721_194103_803.jpg due to unidentifiable image.
# Skipped IMG_20230721_193331_027.jpg due to unidentifiable image.
# Skipped IMG_20230720_173649_077.jpg due to unidentifiable image.
# Skipped IMG_20230720_173638_825.jpg due to unidentifiable image.
# Skipped IMG_20230720_173637_701.jpg due to unidentifiable image.
# Skipped IMG_20230720_173636_071.jpg due to unidentifiable image.
# Skipped IMG_20230719_095046_340.jpg due to unidentifiable image.
# Skipped IMG_20230717_200826_252.jpg due to unidentifiable image.
# Skipped IMG_20230714_174025_731.jpg due to unidentifiable image.
# Skipped IMG_20230710_093034_055.jpg due to unidentifiable image.
# Skipped IMG_20230622_104432_732.jpg due to unidentifiable image.
# Skipped IMG_20230616_115900_899.jpg due to unidentifiable image.
# Skipped IMG_20230614_120811_894.jpg due to unidentifiable image.
# Skipped IMG_20230613_092135_179.jpg due to unidentifiable image.
# Skipped IMG_20230612_210230_415.jpg due to unidentifiable image.
# Skipped IMG_20230612_185252_158.jpg due to unidentifiable image.
# Skipped IMG_20230603_141547_588.jpg due to unidentifiable image.
# Skipped IMG_20230529_074542_247.jpg due to unidentifiable image.
# Skipped IMG_20230525_154700_505.jpg due to unidentifiable image.
# Skipped IMG_20230525_104901_188.jpg due to unidentifiable image.
# Skipped IMG_20230524_070847_481.jpg due to unidentifiable image.
# Skipped IMG_20230522_155225_104.jpg due to unidentifiable image.
# Skipped IMG_20230522_155219_090.jpg due to unidentifiable image.
# Skipped IMG_20230522_155216_818.jpg due to unidentifiable image.
# Skipped IMG_20230522_155215_156.jpg due to unidentifiable image.
# Skipped IMG_20230522_155123_340.jpg due to unidentifiable image.
# Skipped IMG_20230522_154957_674.jpg due to unidentifiable image.
# Skipped IMG_20230515_122925_105.jpg due to unidentifiable image.
# Skipped IMG_20230510_105830_078.jpg due to unidentifiable image.
# Skipped IMG_20230509_212035_751.jpg due to unidentifiable image.
# Skipped IMG_20230509_132611_559.jpg due to unidentifiable image.
# Skipped IMG_20230509_072408_769.jpg due to unidentifiable image.
# Skipped IMG_20230507_094152_098.jpg due to unidentifiable image.
# Skipped IMG_20230505_094107_425.jpg due to unidentifiable image.
# Skipped IMG_20230504_155609_956.jpg due to unidentifiable image.
# Skipped IMG_20230503_091511_037.jpg due to unidentifiable image.
# Skipped IMG_20230503_061407_982.jpg due to unidentifiable image.
# Skipped IMG_20230501_195408_016.jpg due to unidentifiable image.
# Skipped IMG_20230501_122655_980.jpg due to unidentifiable image.
# Skipped IMG_20230430_202130_572.jpg due to unidentifiable image.
# Skipped IMG_20230430_202129_014.jpg due to unidentifiable image.
# Skipped IMG_20230430_202129_140.jpg due to unidentifiable image.
# Skipped IMG_20230430_202116_384.jpg due to unidentifiable image.
# Skipped IMG_20230430_202116_449.jpg due to unidentifiable image.
# Skipped IMG_20230430_202116_761.jpg due to unidentifiable image.
# Skipped IMG_20230429_155825_169.jpg due to unidentifiable image.
# Skipped IMG_20230429_004509_286.jpg due to unidentifiable image.
# Skipped IMG_20230428_113740_420.jpg due to unidentifiable image.
# Skipped IMG_20230428_113551_962.jpg due to unidentifiable image.
# Skipped IMG_20230428_113222_404.jpg due to unidentifiable image.
# Skipped IMG_20230427_201752_736.jpg due to unidentifiable image.
# Skipped IMG_20230427_201420_420.jpg due to unidentifiable image.
# Skipped IMG_20230426_183523_816.jpg due to unidentifiable image.
# Skipped IMG_20230422_145159_422.jpg due to unidentifiable image.
# Skipped IMG_20230420_134606_000.jpg due to unidentifiable image.
# Skipped IMG_20230420_133836_783.jpg due to unidentifiable image.
# Skipped IMG_20230419_123903_072.jpg due to unidentifiable image.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# Finished processing all images.

# %%
# Create DataFrame
df = pd.DataFrame(image_data)

# Export DataFrame to CSV
df.to_csv('/content/drive/MyDrive/Colab Notebooks/stories_archive/imagedatajan24.csv', index=False)

print("Data saved successfully.")
# Out:
# Data saved successfully.
